# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\OneDrive\Documents\Dataset\New Portfolio\Tasty Sushi\sushi_restaurant.csv")
df
# Out:
#       Order ID First Name  Last Name  Gender               City  Order Date  \
# 0            1   Isabella      Smith  Female            Burnley  2021-12-04
# 1            2      Ethan   Anderson  Female            Salford  2022-01-25
# 2            3     Oliver        Lee  Female          Lancaster  2023-09-04
# 3            4     Amelia  Hernandez    Male            Burnley  2024-07-09
# 4            5        Mia     Thomas  Female         Manchester  2023-04-22
# ...        ...        ...        ...     ...                ...         ...
# 9995      9996        Ava      Brown  Female               Bury  2023-04-02
# 9996      9997     Amelia      Brown    Male            Salford  2020-02-14
# 9997      9998     Sophia     Taylor  Female            Preston  2024-01-09
# 9998      9999      Henry     Martin  Female             Bolton  2021-06-26
# 9999     10000        Mia        Lee  Female  Barrow-in-Furness  2022-10-18
#
#      Order Time Order Type     Category      Subcategory  Price  Quantity  \
# 0         15:57     Eat-in  Street food            Gyoza   1.60         2
# 1         16:44     Eat-in         Maki        Hoso Maki   6.33         3
# 2         18:24     Eat-in         Maki     Rainbow Roll   4.97         3
# 3         14:53     Eat-in         Maki          Uramaki   5.18         1
# 4         14:49   Takeaway      Sashimi     Crab Sashimi   6.22         4
# ...         ...        ...          ...              ...    ...       ...
# 9995      16:00     Eat-in  Street food         Takoyaki   3.72         3
# 9996      11:41   Takeaway        Ramen       Shio Ramen   6.53         5
# 9997      14:10     Eat-in         Maki  Spicy Tuna Roll   5.27         2
# 9998      13:21     Eat-in       Temaki       Spicy Tuna   3.28         5
# 9999      17:41     Eat-in  Street food          Karaage   3.51         4
#
#       Total Price Customer Review Weather  Payment Method
# 0            3.20       Excellent   Windy     Credit Card
# 1           18.99       Excellent   Sunny     Credit Card
# 2           14.91       Excellent   Windy            Cash
# 3            5.18            Good   Sunny      Debit Card
# 4           24.88       Excellent   Sunny  Mobile Payment
# ...           ...             ...     ...             ...
# 9995        11.16       Excellent   Sunny  Mobile Payment
# 9996        32.65       Excellent   Sunny     Credit Card
# 9997        10.54       Excellent   Windy            Cash
# 9998        16.40       Excellent   Windy            Cash
# 9999        14.04       Excellent   Sunny     Credit Card
#
# [10000 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         10000 non-null  int64
#  1   First Name       10000 non-null  object
#  2   Last Name        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   City             10000 non-null  object
#  5   Order Date       10000 non-null  object
#  6   Order Time       10000 non-null  object
#  7   Order Type       10000 non-null  object
#  8   Category         10000 non-null  object
#  9   Subcategory      10000 non-null  object
#  10  Price            10000 non-null  float64
#  11  Quantity         10000 non-null  int64
#  12  Total Price      10000 non-null  float64
#  13  Customer Review  10000 non-null  object
#  14  Weather          10000 non-null  object
#  15  Payment Method   10000 non-null  object
# dtypes: float64(2), int64(2), object(12)
# memory usage: 1.2+ MB

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='mixed').dt.strftime('%d/%m/%Y')

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Order ID         10000 non-null  int64
#  1   First Name       10000 non-null  object
#  2   Last Name        10000 non-null  object
#  3   Gender           10000 non-null  object
#  4   City             10000 non-null  object
#  5   Order Date       10000 non-null  datetime64[ns]
#  6   Order Time       10000 non-null  object
#  7   Order Type       10000 non-null  object
#  8   Category         10000 non-null  object
#  9   Subcategory      10000 non-null  object
#  10  Price            10000 non-null  float64
#  11  Quantity         10000 non-null  int64
#  12  Total Price      10000 non-null  float64
#  13  Customer Review  10000 non-null  object
#  14  Weather          10000 non-null  object
#  15  Payment Method   10000 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(2), object(11)
# memory usage: 1.2+ MB

# %%
df['Year'] = df['Order Date'].dt.year

# %%
df.head()
# Out:
#    Order ID First Name  Last Name  Gender        City Order Date Order Time  \
# 0         1   Isabella      Smith  Female     Burnley 2021-04-12      15:57
# 1         2      Ethan   Anderson  Female     Salford 2022-01-25      16:44
# 2         3     Oliver        Lee  Female   Lancaster 2023-04-09      18:24
# 3         4     Amelia  Hernandez    Male     Burnley 2024-09-07      14:53
# 4         5        Mia     Thomas  Female  Manchester 2023-04-22      14:49
#
#   Order Type     Category   Subcategory  Price  Quantity  Total Price  \
# 0     Eat-in  Street food         Gyoza   1.60         2         3.20
# 1     Eat-in         Maki     Hoso Maki   6.33         3        18.99
# 2     Eat-in         Maki  Rainbow Roll   4.97         3        14.91
# 3     Eat-in         Maki       Uramaki   5.18         1         5.18
# 4   Takeaway      Sashimi  Crab Sashimi   6.22         4        24.88
#
#   Customer Review Weather  Payment Method  Year
# 0       Excellent   Windy     Credit Card  2021
# 1       Excellent   Sunny     Credit Card  2022
# 2       Excellent   Windy            Cash  2023
# 3            Good   Sunny      Debit Card  2024
# 4       Excellent   Sunny  Mobile Payment  2023

# %%
df.isnull().sum()
# Out:
# Order ID           0
# First Name         0
# Last Name          0
# Gender             0
# City               0
# Order Date         0
# Order Time         0
# Order Type         0
# Category           0
# Subcategory        0
# Price              0
# Quantity           0
# Total Price        0
# Customer Review    0
# Weather            0
# Payment Method     0
# Year               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#    Order ID First Name  Last Name  Gender        City Order Date Order Time  \
# 0         1   Isabella      Smith  Female     Burnley 2021-04-12      15:57
# 1         2      Ethan   Anderson  Female     Salford 2022-01-25      16:44
# 2         3     Oliver        Lee  Female   Lancaster 2023-04-09      18:24
# 3         4     Amelia  Hernandez    Male     Burnley 2024-09-07      14:53
# 4         5        Mia     Thomas  Female  Manchester 2023-04-22      14:49
#
#   Order Type     Category   Subcategory  Price  Quantity  Total Price  \
# 0     Eat-in  Street food         Gyoza   1.60         2         3.20
# 1     Eat-in         Maki     Hoso Maki   6.33         3        18.99
# 2     Eat-in         Maki  Rainbow Roll   4.97         3        14.91
# 3     Eat-in         Maki       Uramaki   5.18         1         5.18
# 4   Takeaway      Sashimi  Crab Sashimi   6.22         4        24.88
#
#   Customer Review Weather  Payment Method  Year
# 0       Excellent   Windy     Credit Card  2021
# 1       Excellent   Sunny     Credit Card  2022
# 2       Excellent   Windy            Cash  2023
# 3            Good   Sunny      Debit Card  2024
# 4       Excellent   Sunny  Mobile Payment  2023

# %%
df.shape
# Out:
# (10000, 17)

# %%
df['Category'].value_counts()
# Out:
# Category
# Sashimi        1768
# Ramen          1696
# Temaki         1687
# Street food    1647
# Nigiri         1625
# Maki           1577
# Name: count, dtype: int64

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Credit Card       3979
# Debit Card        3071
# Cash              1974
# Mobile Payment     976
# Name: count, dtype: int64

# %%
sns.barplot(data = df, x= 'Category', y = 'Total Price')
# Out:
# <Axes: xlabel='Category', ylabel='Total Price'>

# %%
sns.lineplot(data = df, x = 'Year', y = 'Total Price')
# Out:
# <Axes: xlabel='Year', ylabel='Total Price'>

# %%
df.drop(columns = ['Order ID', 'Order Date', 'Order Time'], inplace=True)

# %%
df.head()
# Out:
#   First Name  Last Name  Gender        City Order Type     Category  \
# 0   Isabella      Smith  Female     Burnley     Eat-in  Street food
# 1      Ethan   Anderson  Female     Salford     Eat-in         Maki
# 2     Oliver        Lee  Female   Lancaster     Eat-in         Maki
# 3     Amelia  Hernandez    Male     Burnley     Eat-in         Maki
# 4        Mia     Thomas  Female  Manchester   Takeaway      Sashimi
#
#     Subcategory  Price  Quantity  Total Price Customer Review Weather  \
# 0         Gyoza   1.60         2         3.20       Excellent   Windy
# 1     Hoso Maki   6.33         3        18.99       Excellent   Sunny
# 2  Rainbow Roll   4.97         3        14.91       Excellent   Windy
# 3       Uramaki   5.18         1         5.18            Good   Sunny
# 4  Crab Sashimi   6.22         4        24.88       Excellent   Sunny
#
#    Payment Method  Year
# 0     Credit Card  2021
# 1     Credit Card  2022
# 2            Cash  2023
# 3      Debit Card  2024
# 4  Mobile Payment  2023

# %%
df.to_excel('Sushi.xlsx', index=False)
